# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

import pandas as pd


cv = CountVectorizer()

textdata = ['The cat love to eat', 'The dog like to eat', "The cat love to chase the dog"]
# print()
# print(cv.get_feature_names_out())


pd.DataFrame(cv.fit_transform(textdata).toarray(), columns = cv.get_feature_names_out())
# Out:
#    cat  chase  dog  eat  like  love  the  to
# 0    1      0    0    1     0     1    1   1
# 1    0      0    1    1     1     0    1   1
# 2    1      1    1    0     0     1    2   1

# %%
cv_tf = TfidfVectorizer()

textdata = ['The cat love to eat', 'The dog like to eat', "The cat love to chase the dog"]



pd.DataFrame(cv_tf.fit_transform(textdata).toarray(), columns = cv.get_feature_names_out())
# Out:
#         cat     chase       dog       eat      like      love       the  \
# 0  0.487591  0.000000  0.000000  0.487591  0.000000  0.487591  0.378658
# 1  0.000000  0.000000  0.450145  0.450145  0.591887  0.000000  0.349578
# 2  0.359341  0.472491  0.359341  0.000000  0.000000  0.359341  0.558121
#
#          to
# 0  0.378658
# 1  0.349578
# 2  0.279061

# %%
cv_tf.vocabulary_
# Out:
# {'the': 6,
#  'cat': 0,
#  'love': 5,
#  'to': 7,
#  'eat': 3,
#  'dog': 2,
#  'like': 4,
#  'chase': 1}

# %%
cv = CountVectorizer(stop_words='english')

textdata = ['The cat love to eat', 'The dog like to eat', "The cat love to chase the dog"]
# print()
# print(cv.get_feature_names_out())


mydf = pd.DataFrame(cv.fit_transform(textdata).toarray(), columns = cv.get_feature_names_out())

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Set the random seed for reproducibility
np.random.seed(42)

# Generate random data for heights (in cm)
# Assuming average height is 160 cm with a standard deviation of 10 cm
heights = np.random.normal(loc=160, scale=10, size=100)

# Generate random data for weights (in kg)
# Assuming weight is correlated with height
weights = heights * 0.5 + np.random.normal(loc=0, scale=5, size=100)

# Create a pandas DataFrame
data = pd.DataFrame({'Height': heights, 'Weight': weights})

# Display the first few rows of the DataFrame
print(data.head())

# Visualize the data
plt.figure(figsize=(10, 6))
plt.scatter(data['Height'], data['Weight'], alpha=0.7, edgecolors='w', s=100)
plt.title('Height vs. Weight of Students')
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.grid(True)
plt.show()
# Out:
#        Height     Weight
# 0  164.967142  75.406717
# 1  158.617357  77.205452
# 2  166.476885  81.524870
# 3  175.230299  83.603763
# 4  157.658466  78.022805

# %%
data.corr()
# Out:
#           Height    Weight
# Height  1.000000  0.635724
# Weight  0.635724  1.000000

# %%
import seaborn as sns

sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Set the random seed for reproducibility
np.random.seed(42)

# Generate random data for heights (in cm)
# Assuming average height is 160 cm with a standard deviation of 10 cm
heights = np.random.normal(loc=160, scale=10, size=100)

# Generate strongly correlated random data for weights (in kg)
# Reducing the noise to make the correlation stronger
weights = heights * 0.5 + np.random.normal(loc=0, scale=2, size=100)

# Create a pandas DataFrame
data = pd.DataFrame({'Height': heights, 'Weight': weights})

# Display the first few rows of the DataFrame
print(data.head())

# Calculate the correlation
correlation = data.corr()
print("Correlation matrix:\n", correlation)

# Visualize the data
plt.figure(figsize=(10, 6))
plt.scatter(data['Height'], data['Weight'], alpha=0.7, edgecolors='w', s=100)
plt.title('Height vs. Weight of Students')
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.grid(True)
plt.show()
# Out:
#        Height     Weight
# 0  164.967142  79.652829
# 1  158.617357  78.467388
# 2  166.476885  82.553014
# 3  175.230299  86.010595
# 4  157.658466  78.506662
# Correlation matrix:
#           Height   Weight
# Height  1.00000  0.91484
# Weight  0.91484  1.00000

# %%
data.corr()
# Out:
#          Height   Weight
# Height  1.00000  0.91484
# Weight  0.91484  1.00000

# %%
import pandas as pd

# %%
import pandas as pd

# Example sentences to use in the dataframe
sentences = [
    "The quick brown fox jumps over the lazy dog",
    "Python is a great programming language",
    "Artificial intelligence is transforming the world",
    "Data science is a multidisciplinary field",
    "Machine learning is a subset of AI",
    "Big data analytics can uncover hidden patterns",
    "Deep learning models require a lot of data",
    "Natural language processing deals with text data",
    "Computer vision is an exciting field",
    "Neural networks are inspired by the human brain",
    "Supervised learning requires labeled data",
    "Unsupervised learning finds hidden structures in data",
    "Reinforcement learning is used in robotics",
    "Feature engineering is crucial for model performance",
    "Model evaluation metrics are important",
    "Hyperparameter tuning can improve model accuracy",
    "Cross-validation is used to validate models",
    "Overfitting occurs when a model is too complex",
    "Underfitting occurs when a model is too simple",
    "Ensemble methods combine multiple models",
    "Random forests are an ensemble method",
    "Gradient boosting is a powerful technique",
    "Support vector machines are used for classification",
    "Clustering algorithms group similar data points",
    "Principal component analysis reduces dimensionality",
    "Time series analysis is used for forecasting",
    "Anomaly detection finds unusual patterns",
    "Regression analysis predicts continuous values",
    "Classification predicts categorical outcomes",
    "Logistic regression is used for binary classification",
    "Decision trees are simple and interpretable",
    "K-means clustering is a popular algorithm",
    "Hierarchical clustering builds a tree of clusters",
    "Association rule learning finds relationships",
    "Collaborative filtering is used in recommendation systems",
    "Content-based filtering recommends similar items",
    "Deep neural networks have multiple layers",
    "Convolutional neural networks are used for image data",
    "Recurrent neural networks are used for sequential data",
    "Long short-term memory networks handle long dependencies",
    "Generative adversarial networks create realistic data",
    "Transfer learning leverages pre-trained models",
    "Autoencoders learn efficient representations",
    "Dimensionality reduction simplifies data",
    "Bayesian networks represent probabilistic relationships",
    "Markov models are used for sequential data",
    "Hidden Markov models are used in speech recognition",
    "Monte Carlo simulations are used for uncertainty",
    "Optimization algorithms find the best solutions",
    "Gradient descent is used to minimize loss functions"
]

# Repeat the sentences to ensure we have at least 50 rows
sentences *= (50 // len(sentences)) + 1

# Create a DataFrame with 50 rows, each containing a list of words
data = {'words': [sentence.split() for sentence in sentences[:50]]}

df = pd.DataFrame(data)

print(df)
# Out:
#                                                 words
# 0   [The, quick, brown, fox, jumps, over, the, laz...
# 1       [Python, is, a, great, programming, language]
# 2   [Artificial, intelligence, is, transforming, t...
# 3    [Data, science, is, a, multidisciplinary, field]
# 4          [Machine, learning, is, a, subset, of, AI]
# 5   [Big, data, analytics, can, uncover, hidden, p...
# 6   [Deep, learning, models, require, a, lot, of, ...
# 7   [Natural, language, processing, deals, with, t...
# 8         [Computer, vision, is, an, exciting, field]
# 9   [Neural, networks, are, inspired, by, the, hum...
# 10    [Supervised, learning, requires, labeled, data]
# 11  [Unsupervised, learning, finds, hidden, struct...
# 12  [Reinforcement, learning, is, used, in, robotics]
# 13  [Feature, engineering, is, crucial, for, model...
# 14       [Model, evaluation, metrics, are, important]
# 15  [Hyperparameter, tuning, can, improve, model, ...
# ...

# %%
#using iloc, we can select the item beased on the index (Thats whau they named it (i)loc)

df.iloc[0, 0]
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
def measure_len(text):
    return len(text)

# %%
# first way to apply the function on each word

result = []
for word in df.iloc[0, 0]:
    # print(measure_len(word))
    result.append(measure_len(word))



print(result)
# Out:
# [3, 5, 5, 3, 5, 4, 3, 4, 3]

# %%
# Second way (APPLY)


df['words'].apply(measure_len)


# see that it only measure the len of the list
# Out:
# 0     9
# 1     6
# 2     6
# 3     6
# 4     7
# 5     7
# 6     8
# 7     7
# 8     6
# 9     8
# 10    5
# 11    7
# 12    6
# 13    7
# 14    5
# 15    6
# 16    6
# 17    8
# 18    8
# 19    5
# 20    6
# 21    6
# 22    7
# 23    6
# 24    5
# 25    7
# 26    5
# 27    5
# 28    4
# 29    7
# 30    6
# 31    6
# 32    7
# 33    5
# 34    7
# 35    5
# 36    6
# 37    8
# 38    8
# 39    7
# 40    6
# 41    5
# 42    4
# 43    4
# 44    5
# 45    7
# 46    8
# 47    7
# 48    6
# 49    8
# Name: words, dtype: int64

# %%
df['words'].apply(lambda row: [measure_len(word) for word in row] )
# Out:
# 0     [3, 5, 5, 3, 5, 4, 3, 4, 3]
# 1             [6, 2, 1, 5, 11, 8]
# 2           [10, 12, 2, 12, 3, 5]
# 3             [4, 7, 2, 1, 17, 5]
# 4           [7, 8, 2, 1, 6, 2, 2]
# 5           [3, 4, 9, 3, 7, 6, 8]
# 6        [4, 8, 6, 7, 1, 3, 2, 4]
# 7          [7, 8, 10, 5, 4, 4, 4]
# 8              [8, 6, 2, 2, 8, 5]
# 9        [6, 8, 3, 8, 2, 3, 5, 5]
# 10               [10, 8, 8, 7, 4]
# 11        [12, 8, 5, 6, 10, 2, 4]
# 12            [13, 8, 2, 4, 2, 8]
# 13        [7, 11, 2, 7, 3, 5, 11]
# 14               [5, 10, 7, 3, 9]
# 15            [14, 6, 3, 7, 5, 8]
# 16            [16, 2, 4, 2, 8, 6]
# 17      [11, 6, 4, 1, 5, 2, 3, 7]
# 18      [12, 6, 4, 1, 5, 2, 3, 6]
# 19                [8, 7, 7, 8, 6]
# 20             [6, 7, 3, 2, 8, 6]
# 21             [8, 8, 2, 1, 8, 9]
# 22         [7, 6, 8, 3, 4, 3, 14]
# 23           [10, 10, 5, 7, 4, 6]
# 24               [9, 9, 8, 7, 14]
# 25         [4, 6, 8, 2, 4, 3, 11]
# 26                [7, 9, 5, 7, 8]
# ...

# %%
mylist = [5, 6, 7, 8, 9, 10]


second_list = [i * 10   for i in mylist]
second_list
# Out:
# [50, 60, 70, 80, 90, 100]

# %%
mylist = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
newtext = ''

#first method : 
for i in mylist:
    newtext = newtext + " " + i

newtext
# Out:
# ' The quick brown fox jumps over the lazy dog'

# %%
mylist = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

#second method

' '.join(mylist)
# Out:
# 'The quick brown fox jumps over the lazy dog'

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt


#initializing the wordcloud

wordcloud = WordCloud(width=  500, height=500).generate('The quick brown fox jumps over the lazy dog dog dog dog dog dog dog dog dog dog dog dog dog dog dog dog dog dog')



plt.figure(figsize=(10, 10))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
mylist
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
import pandas as pd

# Example sentences to use in the dataframe
sentences = [
    "The quick brown fox jumps over the lazy dog",
    "Python is a great programming language",
    "Artificial intelligence is transforming the world",
    "Data science is a multidisciplinary field",
    "Machine learning is a subset of AI",
    "Big data analytics can uncover hidden patterns",
    "Deep learning models require a lot of data",
    "Natural language processing deals with text data",
    "Computer vision is an exciting field",
    "Neural networks are inspired by the human brain",
    "Supervised learning requires labeled data",
    "Unsupervised learning finds hidden structures in data",
    "Reinforcement learning is used in robotics",
    "Feature engineering is crucial for model performance",
    "Model evaluation metrics are important",
    "Hyperparameter tuning can improve model accuracy",
    "Cross-validation is used to validate models",
    "Overfitting occurs when a model is too complex",
    "Underfitting occurs when a model is too simple",
    "Ensemble methods combine multiple models",
    "Random forests are an ensemble method",
    "Gradient boosting is a powerful technique",
    "Support vector machines are used for classification",
    "Clustering algorithms group similar data points",
    "Principal component analysis reduces dimensionality",
    "Time series analysis is used for forecasting",
    "Anomaly detection finds unusual patterns",
    "Regression analysis predicts continuous values",
    "Classification predicts categorical outcomes",
    "Logistic regression is used for binary classification",
    "Decision trees are simple and interpretable",
    "K-means clustering is a popular algorithm",
    "Hierarchical clustering builds a tree of clusters",
    "Association rule learning finds relationships",
    "Collaborative filtering is used in recommendation systems",
    "Content-based filtering recommends similar items",
    "Deep neural networks have multiple layers",
    "Convolutional neural networks are used for image data",
    "Recurrent neural networks are used for sequential data",
    "Long short-term memory networks handle long dependencies",
    "Generative adversarial networks create realistic data",
    "Transfer learning leverages pre-trained models",
    "Autoencoders learn efficient representations",
    "Dimensionality reduction simplifies data",
    "Bayesian networks represent probabilistic relationships",
    "Markov models are used for sequential data",
    "Hidden Markov models are used in speech recognition",
    "Monte Carlo simulations are used for uncertainty",
    "Optimization algorithms find the best solutions",
    "Gradient descent is used to minimize loss functions"
]

# Repeat the sentences to ensure we have at least 50 rows
sentences *= (50 // len(sentences)) + 1

# Create a DataFrame with 50 rows, each containing a list of words
data = {'words':sentences}

df = pd.DataFrame(data)

print(df)
# Out:
#                                                 words
# 0         The quick brown fox jumps over the lazy dog
# 1              Python is a great programming language
# 2   Artificial intelligence is transforming the world
# 3           Data science is a multidisciplinary field
# 4                  Machine learning is a subset of AI
# ..                                                ...
# 95         Markov models are used for sequential data
# 96  Hidden Markov models are used in speech recogn...
# 97   Monte Carlo simulations are used for uncertainty
# 98    Optimization algorithms find the best solutions
# 99  Gradient descent is used to minimize loss func...
#
# [100 rows x 1 columns]

# %%
result = ''

for i in df['words']:
    result = ' '.join(i)

print(result)
# Out:
# G r a d i e n t   d e s c e n t   i s   u s e d   t o   m i n i m i z e   l o s s   f u n c t i o n s

# %%
long_text = ' '.join( [ text for text in df['words']])

# %%
print(long_text)
# Out:
# The quick brown fox jumps over the lazy dog Python is a great programming language Artificial intelligence is transforming the world Data science is a multidisciplinary field Machine learning is a subset of AI Big data analytics can uncover hidden patterns Deep learning models require a lot of data Natural language processing deals with text data Computer vision is an exciting field Neural networks are inspired by the human brain Supervised learning requires labeled data Unsupervised learning finds hidden structures in data Reinforcement learning is used in robotics Feature engineering is crucial for model performance Model evaluation metrics are important Hyperparameter tuning can improve model accuracy Cross-validation is used to validate models Overfitting occurs when a model is too complex Underfitting occurs when a model is too simple Ensemble methods combine multiple models Random forests are an ensemble method Gradient boosting is a powerful technique Support vector machines a
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt


#initializing the wordcloud

wordcloud = WordCloud(width=  500, height=500).generate(long_text)



plt.figure(figsize=(10, 10))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
