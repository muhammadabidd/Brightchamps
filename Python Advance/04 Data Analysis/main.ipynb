# %%
with open('train.csv', 'r') as data:
    print(data.read())
# Out:
# City,Month,Year,Decibel_Level,Traffic_Density,Green_Space_Area,Air_Quality_Index,Happiness_Score,Cost_of_Living_Index,Healthcare_Index
# New York,January,2024,70,High,35,40,6.5,100,80
# Los Angeles,January,2024,65,Medium,40,50,6.8,90,75
# Chicago,January,2024,60,Medium,30,55,7.0,85,70
# London,January,2024,55,High,50,60,7.2,110,85
# Paris,January,2024,60,High,45,65,6.9,95,80
# Berlin,January,2024,50,Low,55,35,7.5,80,85
# Tokyo,January,2024,65,High,30,70,6.0,120,90
# Seoul,January,2024,70,High,25,75,5.8,105,75
# Mumbai,January,2024,80,Very High,15,80,4.5,70,60
# Sydney,January,2024,55,Low,60,30,7.8,115,88
# Istanbul,February,2024,75,High,45,85,6.8,75,70
# Rio de Janeiro,February,2024,65,Medium,50,55,6.5,80,75
# Toronto,February,2024,60,Medium,55,40,7.1,95,85
# Mexico City,February,2024,70,Very High,35,90,5.2,65,60
# Cape Town,February,2024,55,Low,60,45,7.6,70,80
# Bangkok,February,2024,80,High,25,110,4.0,50,55
# Buenos Aires,February,2024,65,High,40,60,6.1,60,75
# ...

# %%
import csv

with open('train.csv', 'r') as data:
    
    
    print(csv.reader(data))

    for i in csv.reader(data):
        print(i[3])
# Out:
# ...
# Decibel_Level
# 70
# 65
# 60
# 55
# 60
# 50
# 65
# 70
# 80
# 55
# 75
# 65
# 60
# 70
# 55
# 80
# 65
# 50
# 75
# 60
# 65
# 70
# 75
# 60
# 55
# 55
# 50
# 60
# 65
# 55
# 60
# 50
# 55
# 50
# 55
# 60
# 65
# 60
# 70
# 75
# 70
# 75
# 65
# 70
# 75
# 65
# 70
# 75
# 65
# 70
# 75
# 80
# 80
# 75
# 70
# 75
# 80
# 85
# 80
# 85
# 90
# 75
# 80
# 75
# 80
# 85
# 80
# 75
# 85
# 90
# 85
# 60
# 55
# 60
# 55
# 50
# 55
# 50
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# ...

# %%
import csv

with open('train.csv', 'r') as data:
    
    all_data = list(csv.reader(data))
    # print(len(all_data))

    for i in range(1, len(all_data)):
        print(all_data[i][3])
# Out:
# 70
# 65
# 60
# 55
# 60
# 50
# 65
# 70
# 80
# 55
# 75
# 65
# 60
# 70
# 55
# 80
# 65
# 50
# 75
# 60
# 65
# 70
# 75
# 60
# 55
# 55
# 50
# 60
# 65
# 55
# 60
# 50
# 55
# 50
# 55
# 60
# 65
# 60
# 70
# 75
# 70
# 75
# 65
# 70
# 75
# 65
# 70
# 75
# 65
# 70
# 75
# 80
# 80
# 75
# 70
# 75
# 80
# 85
# 80
# 85
# 90
# 75
# 80
# 75
# 80
# 85
# 80
# 75
# 85
# 90
# 85
# 60
# 55
# 60
# 55
# 50
# 55
# 50
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# 55
# 60
# 55
# 50
# ...
