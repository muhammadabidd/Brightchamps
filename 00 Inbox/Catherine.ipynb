# %%
print('* ' * 1)
print('* ' * 2)
print('* ' * 3)
print('* ' * 4)
print('* ' * 5)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
row = int(input("How Many Row that you want?"))

for i in range(1, row):
    print('* ' * i)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * * * *
# * * * * * * * *
# * * * * * * * * *
# * * * * * * * * * *
# * * * * * * * * * * *
# * * * * * * * * * * * *
# * * * * * * * * * * * * *
# * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# ...

# %%
print(' ' * 5 +'* ' * 1)
print(' ' * 4 +'* ' * 2)
print(' ' * 3 +'* ' * 3)
print(' ' * 2 +'* ' * 4)
print(' ' * 1 +'* ' * 5)
# Out:
#      *
#     * *
#    * * *
#   * * * *
#  * * * * *

# %%
row = int(input("How Many Row that you want?"))

for i in range(1, row + 1):
    print(f'{row+1 - i} and {i}')
    print(' ' * (row + 1 - i) +'* ' * i)
# Out:
# 10 and 1
#           *
# 9 and 2
#          * *
# 8 and 3
#         * * *
# 7 and 4
#        * * * *
# 6 and 5
#       * * * * *
# 5 and 6
#      * * * * * *
# 4 and 7
#     * * * * * * *
# 3 and 8
#    * * * * * * * *
# 2 and 9
#   * * * * * * * * *
# 1 and 10
#  * * * * * * * * * *

# %%
print('* ' * 1)
print('* ' * 2)
print('* ' * 3)
print('* ' * 4)
print('* ' * 5)


print('* ' * 5)
print('* ' * 4)
print('* ' * 3)
print('* ' * 2)
print('* ' * 1)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
import time


print("Seconds since January 1, 1970 (Unix Epoch):", time.time()%1440)

time.sleep(66)

print("Seconds since January 1, 1970 (Unix Epoch):", time.time()%1440)
# Out:
# Seconds since January 1, 1970 (Unix Epoch): 889.0633130073547
# Seconds since January 1, 1970 (Unix Epoch): 955.0674440860748

# %%
help(time)
# Out:
# Help on built-in module time:
#
# NAME
#     time - This module provides various functions to manipulate time values.
#
# DESCRIPTION
#     There are two standard representations of time.  One is the number
#     of seconds since the Epoch, in UTC (a.k.a. GMT).  It may be an integer
#     or a floating point number (to represent fractions of seconds).
#     The Epoch is system-defined; on Unix, it is generally January 1st, 1970.
#     The actual value can be retrieved by calling gmtime(0).
#
#     The other representation is a tuple of 9 integers giving local time.
#     The tuple items are:
#       year (including century, e.g. 1998)
#       month (1-12)
#       day (1-31)
#       hours (0-23)
#       minutes (0-59)
#       seconds (0-59)
#       weekday (0-6, Monday is 0)
#       Julian day (day in the year, 1-366)
#       DST (Daylight Savings Time) flag (-1, 0 or 1)
#     If the DST flag is 0, the time is given in the regular time zone;
# ...

# %%
waktu = time.time()

waktu.hour
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 3
#       1 waktu = time.time()
# ----> 3 waktu.hour
#
# AttributeError: 'float' object has no attribute 'hour'

# %%
import datetime

# Get the current time
current_time = datetime.datetime.now()

# Extract the hour from the current time
current_hour = current_time.minute

print("Current hour:", current_hour)




import random

if current_hour != 
value = random.randint(1, 270)
value
# Out:
# Current hour: 23
# 156

# %%
jackpot = 55




while True:

    angka = int(input("Coba Tebak angkanya : "))
    if angka < jackpot:
        print("Angkanya terlalu kecil, tebak akngka yang lebih besar")
    elif angka > jackpot:
        print("Angka terlalu besar")
    elif angka == jackpot:
        print("Anda Benar")
        break
# Out:
# Angkanya terlalu kecil, tebak akngka yang lebih besar
# Angkanya terlalu kecil, tebak akngka yang lebih besar
# Angkanya terlalu kecil, tebak akngka yang lebih besar
# Angkanya terlalu kecil, tebak akngka yang lebih besar
# Angkanya terlalu kecil, tebak akngka yang lebih besar
# Angkanya terlalu kecil, tebak akngka yang lebih besar
# Angkanya terlalu kecil, tebak akngka yang lebih besar
# Angkanya terlalu kecil, tebak akngka yang lebih besar
# Angka terlalu besar
# Angka terlalu besar
# Angka terlalu besar
# Anda Benar

# %%
from datetime import datetime
import time
import pytz    #python timezone
# from replit import audio
india = pytz.timezone('Asia/Kolkata')
now = datetime.now(india)
print(now)
alarm = input("Enter the time of alarm to be set in 12 hour format-HH:MM:SS:(AM/PM)\n")
hour = alarm[0:2]
if (hour>"12"):
  hour=hour-12
else:
  hour
minute = alarm[3:5]
seconds = alarm[6:8]
period = alarm[9:11].upper()
print("alarm set..")

        
        
while True:
    now = datetime.now(india)
    hournow = now.strftime("%I")
    minutenow = now.strftime("%M")
    secondsnow = now.strftime("%S")
    periodnow = now.strftime("%p")
    print(f"Current time: {int(hournow):02d}:{int(minutenow):02d}:{int(secondsnow):02d}")
    time.sleep(1)
    if(period == periodnow):
        if(hour == hournow):
            if(minute == minutenow):
                if(seconds == secondsnow):
                    print("Wake Up!")
                    # source = audio.play_file('Tring Tring Tring.mp3')
                    while True:
                       pass
# Out:
# 2024-05-24 13:40:15.188488+05:30
# alarm set..
# Current time: 01:40:56
# Current time: 01:40:57
# Current time: 01:40:58
# Current time: 01:40:59
# Current time: 01:41:00
# Current time: 01:41:01
# Current time: 01:41:02
# Current time: 01:41:03
# Current time: 01:41:04
# Current time: 01:41:05
# Current time: 01:41:06
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 28
#      26 periodnow = now.strftime("%p")
#      27 print(f"Current time: {int(hournow):02d}:{int(minutenow):02d}:{int(secondsnow):02d}")
# ---> 28 time.sleep(1)
#      29 if(period == periodnow):
#      30     if(hour == hournow):
#
# KeyboardInterrupt:

# %%
from datetime import datetime as dt
import time
import pytz 

# for i in pytz.all_timezones:
#     print(i)

mytimezone = 'Asia/Jakarta'




print(now.strftime('%H'))     # 24 hour format (HOUR)
print(now.strftime('%I'))     # twelve hour format (HOUR)
print(now.strftime('%M')) 
print(now.strftime('%S')) 


print(now.strftime('%H:%M:%S')) 
print(now.strftime('%m %d %Y')) 





run_hour =  int(input("insert the hour : "))
run_minute = int(input("insert the minute : "))
run_second = int(input("insert the second : "))


while True :

    tz = pytz.timezone(mytimezone)
    now = dt.now(tz)
    current_hour = now.strftime('%H')
    current_minute = now.strftime('%M')
    current_sec = now.strftime('%S')

    current_time = now.strftime('%H:%M:%S')



    run_combined = run_hour + ":" + run_minute + ":" + run_second





    print(f'Current Hour is : {current_time}')


    if current_hour == run_hour &  current_minute == run_minute & current_sec == run_second:
        print("ITS THE TIMESSSSSS")





    time.sleep(1)
# Out:
# 15
# 03
# 55
# 43
# 15:55:43
# 05 24 2024
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 43
#      37 current_sec = now.strftime('%S')
#      39 current_time = now.strftime('%H:%M:%S')
# ---> 43 run_combined = run_hour + ":" + run_minute + ":" + run_second
#      49 print(f'Current Hour is : {current_time}')
#      52 if current_hour == run_hour &  current_minute == run_minute & current_sec == run_second:
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(name)
print(age)
print(grade)
# Out:
# abid
# 12
# 12

# %%
all_students_data = {}

# only for making the function, not calling it
def add_student():
    name = input("Enter student name: ")
    age = int(input("Enter student age: "))
    grade = input("Enter student grade: ")
    id = len(all_students_data) + 1

    all_students_data[id] = {
        "NAMA" : name,
        "UMUR" : age,
        "KELAS" : grade
    }
    print(f"Student {name} added with ID: {id}")




def print_All_detail(id):
    student = all_students_data.get(id)
    print(f"The student name is : {student['NAMA']}")
    print(f"The student Age is : {student['UMUR']}")
    print(f"The student Grade is : {student['KELAS']}")
    print("--------------------------------")


def remove_student(id):
    if id in all_students_data:

        del all_students_data[id]
        print(f"The student with ID : {id}  has been removed")
    else:
        print("No student with that ID")

# %%
# we can call function in this cell
add_student()
add_student()

print_All_detail(1)
print_All_detail(2)


remove_student(1)
all_students_data
# Out:
# Student Abid added with ID: 1
# Student Bunda added with ID: 2
# The student name is : Abid
# The student Age is : 12
# The student Grade is : 2
# The student name is : Bunda
# The student Age is : 2
# The student Grade is : 2
# {1: {'NAMA': 'Abid', 'UMUR': 12, 'KELAS': '2'},
#  2: {'NAMA': 'Bunda', 'UMUR': 2, 'KELAS': '2'}}

# %%
# Out:
# The student name is : Abid
# The student name is : 12
# The student name is : 12

# %%
emptydic = {}

id = len(emptydic) + 1
emptydic[id] = {'ABid' : 12}


id = len(emptydic) + 1
emptydic[id] = {"Bunga": 13}

id = len(emptydic) + 1
emptydic[id] = {"Bunga": 13}
id = len(emptydic) + 1
emptydic[id] = {"Bunga": 13}
id = len(emptydic) + 1
emptydic[id] = {"Bunga": 13}
id = len(emptydic) + 1
emptydic[id] = {"Bunga": 13}


emptydic
# Out:
# {1: {'ABid': 12},
#  2: {'Bunga': 13},
#  3: {'Bunga': 13},
#  4: {'Bunga': 13},
#  5: {'Bunga': 13},
#  6: {'Bunga': 13}}

# %%
del emptydic[1]

# %%
emptydic
# Out:
# {2: {'Bunga': 13},
#  3: {'Bunga': 13},
#  4: {'Bunga': 13},
#  5: {'Bunga': 13},
#  6: {'Bunga': 13}}

# %%
7 in emptydic
# Out:
# False

# %%
board = [[' ' for _ in range(3)] for _ in range(3)]
print(board)
def drawboard(board):
    for row in board:
        print(" | ".join(row))
        print("-" * 9)
drawboard(board)
# Out:
# [[' ', ' ', ' '], [' ', ' ', ' '], [' ', ' ', ' ']]
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------

# %%
board = [[' ' for _ in range(3)] for _ in range(3)]

def drawboardindex(board):
    line = "-------------"
    print("  0   1   2")
    for i, row in enumerate(board):
        print(i, end=" ")
        for cell in row:
            print(f"| {cell} ", end="")
        print("|")
        print(line)

# %%
board = [[' ' for _ in range(3)] for _ in range(3)]
for i, row in enumerate(board):
    # print(i, end=" ")
    for cell in row:
        # print(f"| {cell} ", end="")
        print(cell, end = "#")
# Out:
#  # # # # # # # # #

# %%
def drawboard(board):
    for row in board:
        print(" | ".join(row))
        print("-" * 9)

def winner(board, player):
    for i in range(3):
        if all(board[i][j] == player for j in range(3)) or all(board[j][i] == player for j in range(3)):
            return True

    if all(board[i][i] == player for i in range(3)) or all(board[i][2 - i] == player for i in range(3)):
        return True

    return False

def boardfull(board):
    return all(board[i][j] != ' ' for i in range(3) for j in range(3))

board = [[' ' for _ in range(3)] for _ in range(3)]
# drawboard(board)


def drawboardindex(board):
    line = "-------------"
    print("  0   1   2")
    for i, row in enumerate(board):
        print(i, end=" ")
        for cell in row:
            print(f"| {cell} ", end="")
        print("|")
        print(line)

drawboardindex(board)
# Out:
#   0   1   2
# 0 |   |   |   |
# -------------
# 1 |   |   |   |
# -------------
# 2 |   |   |   |
# -------------

# %%
boardfull(board)
# Out:
# False

# %%
def drawboard(board):
    for row in board:
        print(" | ".join(row))
        print("-" * 9)

def winner(board, player):
    for i in range(3):
        if all(board[i][j] == player for j in range(3)) or all(board[j][i] == player for j in range(3)):
            return True

    if all(board[i][i] == player for i in range(3)) or all(board[i][2 - i] == player for i in range(3)):
        return True

    return False

def boardfull(board):
    return all(board[i][j] != ' ' for i in range(3) for j in range(3))

def movement():
    while True:
        try:
            row = int(input("Enter row (0, 1, or 2): "))
            col = int(input("Enter column (0, 1, or 2): "))
            if 0 <= row <= 2 and 0 <= col <= 2:
                return row, col
            else:
                print("Invalid input. Please enter a number between 0 and 2.")
        except ValueError:
            print("Invalid input. Please enter a valid number.")

def play():
    board = [[' ' for _ in range(3)] for _ in range(3)]
    players = ['X', 'O']
    current_player = 0
    while True:
        drawboard(board)
        player = players[current_player]
        
        print(f"Player {player}'s turn.")
        row, col = movement()

        if board[row][col] == ' ':
            board[row][col] = player

            if winner(board, player):
                drawboard(board)
                print(f"Player {player} wins!")
          
                play()
                break
            elif boardfull(board):
                drawboard(board)
                print("It's a draw!")
                break

            current_player = 1 - current_player
        else:
          print("That cell is already fille please Try again.")

play()
# Out:
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player X's turn.
#   |   |
# ---------
#   | X |
# ---------
#   |   |
# ---------
# Player O's turn.
# O |   |
# ---------
#   | X |
# ---------
#   |   |
# ---------
# Player X's turn.
# O |   |
# ---------
# X | X |
# ---------
#   |   |
# ---------
# Player O's turn.
# O | O |
# ---------
# X | X |
# ---------
#   |   |
# ---------
# Player X's turn.
# O | O |
# ---------
# X | X | X
# ---------
#   |   |
# ---------
# Player X wins!
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player X's turn.
# Invalid input. Please enter a valid number.
# Invalid input. Please enter a valid number.
# Invalid input. Please enter a valid number.
# Invalid input. Please enter a valid number.
# Invalid input. Please enter a valid number.
# Invalid input. Please enter a valid number.
# Invalid input. Please enter a valid number.
# Invalid input. Please enter a valid number.
# ...

# %%
board =[[' ', ' ', ' '], [' ', ' ', ' '], [' ', ' ', ' ']]
signs = ['X', 'O']
current_player = 0


while True:
    drawboard(board)

    sign = signs[current_player]
    print(f"Player {current_player}'s turn.")

    row, col = int(input("Insert the row")), int(input("Insert the col"))  # costumize this later

    if board[row][col] == ' ':
        board[row][col] = sign
        current_player = 1 - current_player
# Out:
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player 0's turn.
#   |   |
# ---------
#   | X |
# ---------
#   |   |
# ---------
# Player 1's turn.
#   |   |
# ---------
#   | X |
# ---------
#   |   |
# ---------
# Player 1's turn.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 12
#       9 sign = signs[current_player]
#      10 print(f"Player {current_player}'s turn.")
# ---> 12 row, col = int(input("Insert the row")), int(input("Insert the col"))  # costumize this later
#      14 if board[row][col] == ' ':
#      15     board[row][col] = sign
#
# File ~/Library/Python/3.11/lib/python/site-packages/ipykernel/kernelbase.py:1261, in Kernel.raw_input(self, prompt)
#    1259     msg = "raw_input was called, but this frontend does not support input requests."
#    1260     raise StdinNotImplementedError(msg)
# ...
